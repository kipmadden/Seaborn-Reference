# %% [markdown]
# Reference Notebook for plotting with Seaborn
#
# Use of built in datasets from scipy.stats and seaborn modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("diamonds")

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.shape
# Out:
# (53940, 10)

# %%
sns.stripplot(data=df.query('carat == 1.00'), x="price", y="clarity", jitter=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='clarity'>

# %%
sns.swarmplot(data=df.query("carat == 1.00"), x="price", y="clarity")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 86.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.boxplot(data=df.query('carat == 1.00'), x="price", y="clarity")
# Out:
# <AxesSubplot:xlabel='price', ylabel='clarity'>

# %%
sns.violinplot(data=df.query('carat == 1.00'), x="price", y="clarity")
# Out:
# <AxesSubplot:xlabel='price', ylabel='clarity'>

# %%
sns.boxenplot(data=df.query('carat == 1.00'), x="price", y="clarity")
# Out:
# <AxesSubplot:xlabel='price', ylabel='clarity'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.barplot(data=df.query('carat == 1.00'), x="price", y="clarity", hue="cut", ax=ax)
# Out:
# <AxesSubplot:xlabel='price', ylabel='clarity'>

# %%
sns.pointplot(data=df.query('carat == 1.00'), x="price", y="clarity", hue="cut")
# Out:
# <AxesSubplot:xlabel='price', ylabel='clarity'>

# %%
sns.countplot(data=df.query('carat == 1.00'), y="clarity", hue="cut")
# Out:
# <AxesSubplot:xlabel='count', ylabel='clarity'>

# %%
g = sns.catplot(kind="bar", 
            col="color", 
            data=df.query('carat == 1.00'), 
            x="price", 
            y="clarity", 
            hue="cut", 
            col_wrap=1,
           height=10,
           aspect=1.2,
           sharex=True)

# %%
excol = ['x','y','z']
df1 = df.drop(excol, axis=1)
sns.pairplot(df1, hue="color")

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.regplot(data=df.query('color == "E" and clarity == "VS2"'), x="price", y="carat", marker='+')
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
sns.residplot(data=df.query('color == "E" and clarity == "VS2"'), x="price", y="carat")
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
sns.regplot(data=df.query('color == "E" and clarity == "VS2"'), x="price", y="carat", marker='+', order=2)
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
#df['cut'] = df['cut'].cat.as_ordered()
#df = df.set_index('cut')
df.head()
#df.reset_index()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.cut.head()
#sns.regplot(data=df.query('color == "E" and clarity == "VS2"'), x="cut", y="price")
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df['clarity'] = df['clarity'].cat.as_ordered()

# %%
#sns.regplot(data=df, x="clarity", y="price", x_estimator=np.mean, order=2)

# %%
sns.regplot(data=df.query('color == "E" and clarity == "VS2"'), x="price", y="carat", x_bins=20)
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %%
ct = pd.crosstab(df['cut'], df['clarity'], values=df.query('carat == 1.0')['price'],aggfunc='mean').round(0)

# %%
ct.head(15)
# Out:
# clarity         IF     VVS1    VVS2     VS1     VS2     SI1     SI2      I1
# cut
# Ideal      16469.0   9220.0  8148.0  6261.0  6134.0  5122.0  4224.0  3336.0
# Premium     7626.0   8653.0  8021.0  6489.0  5844.0  4880.0  4046.0  2728.0
# Very Good  10446.0   7970.0  8161.0  6656.0  6089.0  4993.0  4215.0  3130.0
# Good       11818.0   6539.0  6896.0  5865.0  5567.0  4652.0  3950.0  2603.0
# Fair           NaN  10752.0  6303.0  5119.0  4804.0  4119.0  3396.0  2190.0

# %%
sns.heatmap(ct)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='cut'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(ct, annot=True, fmt="g",
            cmap="YlGnBu", cbar=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='cut'>

# %%
sns.heatmap(ct, annot=True, fmt="g",
            cmap="YlGnBu", cbar=True, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='cut'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(ct, annot=True, fmt="g",
            cmap="YlGnBu", cbar=True, 
            linewidths=.5, ax=ax,
           center=ct.loc['Premium','IF'])
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='cut'>

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(df1.corr(), annot=True, fmt="g",
            cmap="YlGnBu", cbar=True, linewidths=.8, ax=ax)
# Out:
# <AxesSubplot:>

# %%
g = sns.FacetGrid(df.query('color == "E" and clarity == "VS2" and carat == 1'), col='cut')
g.map(sns.boxplot, 'price', order=['Fair','Good','Very Good','Ideal','Premium'])

# %%
sns.catplot(x='price', data=df.query('color == "E" and clarity == "VS2" and carat == 1'),
              col='cut', kind='box')

# %%
sns.lmplot(x='price', y='carat', data=df.query('clarity == "VS2"'),
              col='cut', row='color')

# %%
g = sns.PairGrid(df.query('clarity == "IF" and cut == "Ideal"'), vars=['carat','price'])
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(df.query('clarity == "IF" and cut == "Ideal"'), vars=['carat','price'])
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
sns.pairplot(df.query('clarity == "IF" and cut == "Ideal"'), 
             vars=['carat','price'],
            kind='reg',
            diag_kind='hist')

# %%
sns.pairplot(df.query('clarity == "IF" and cut == "Ideal"'), 
             vars=['carat','price'],
            kind='reg',
            diag_kind='hist',
            hue='color',
            palette='husl')

# %%
g = sns.JointGrid(data=df.query('clarity == "IF" and cut == "Ideal"'),
                 x="price",
                 y="carat")
g.plot(sns.regplot, sns.kdeplot)

# %%
g = sns.JointGrid(data=df.query('clarity == "IF" and cut == "Ideal"'),
                 x="price",
                 y="carat")
g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot, shade=True)
#g = g.annotate(stats.pearsonr)
g.ax_joint.annotate(stats.pearsonr, xy=(0.1, 2))
plt.tight_layout()

# %%
sns.jointplot(data=df.query('clarity == "VS2" and cut == "Ideal"'),
                 x="price",
                 y="carat",
             kind='hex')

# %%
g = (sns.jointplot(data=df.query('clarity == "VS2" and cut == "Ideal"'),
                 x="price",
                 y="carat",
             kind='scatter', color='g').plot_joint(sns.kdeplot))

# %%
sns.set_style("whitegrid")

sns.jointplot(data=df.query('clarity == "VS2" and cut == "Ideal"'),
                 x="price",
                 y="carat",
             kind='reg')

# %%
sns.set_style("whitegrid")

sns.jointplot(data=df.query('clarity == "IF" and cut == "Ideal"'),
                 x="price",
                 y="carat",
             kind='reg')

# %%
sns.set_style("darkgrid")

sns.jointplot(data=df.query('clarity == "VS2" and cut == "Ideal"'),
                 x="price",
                 y="carat",
             kind='reg')
